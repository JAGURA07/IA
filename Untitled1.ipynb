# %%
import numpy as np

# %%
def F(x):
  return np.sqrt(1-(x/4)**4)

# %%
def monte_carlo(F,a,b,M): 
  s = 0
  for i in range(M): 
    s+= F(a+(b-a)*np.random.uniform(0,1,1))
  return ((b-a)/M)*s[0]

# %%
monte_carlo(F,0,0.25,1000)
# Out:
# 0.2499996436009815
